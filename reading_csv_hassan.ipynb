# %%
# Out:
# ...
# [notice] A new release of pip is available: 23.3.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# This is the dataset from Kaggle Dataset

# %%
import pandas as pd

establishment_df=pd.read_csv("data/Grab SG Restaurants.csv")

establishment_df.head()
# Out:
#           id_source             name                     address    country  \
# 0         SGDD01085    Texas Chicken    Texas Chicken - VivoCity  Singapore
# 1  4-CYTDLPUJEP53N6           Subway           Subway - Vivocity  Singapore
# 2         SGDD05605         LiHO Tea        LiHO Tea - Vivo City  Singapore
# 3         SGDD07548         Wingstop         Wingstop - VivoCity  Singapore
# 4  4-CY2ZLZLTT2EDJ2  Le Shrimp Ramen  Le Shrimp Ramen - Vivocity  Singapore
#
#                                              cuisine currency  delivery_cost  \
# 0  ["Western", "Fast Food", "Halal", "Chicken", "...      SGD          570.0
# 1  ["Healthy", "Sandwiches", "Fast Food", "Halal"...      SGD          570.0
# 2  ["Same Prices In-Store", "Beverages", "Local",...      SGD          560.0
# 3  ["Halal", "Chicken", "Fast Food", "Burger", "W...      SGD          560.0
# 4          ["Japanese", "Ramen", "Noodles", "Asian"]      SGD          570.0
#
# ...

# %% [markdown]
# ## Exploratory Data Analysis
#
# Simple exploratory Data Analysis to understand the data

# %%
establishment_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16136 entries, 0 to 16135
# Data columns (total 19 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id_source         16136 non-null  object
#  1   name              16130 non-null  object
#  2   address           16136 non-null  object
#  3   country           16136 non-null  object
#  4   cuisine           16134 non-null  object
#  5   currency          16117 non-null  object
#  6   delivery_cost     16085 non-null  float64
#  7   lat               16136 non-null  float64
#  8   lon               16136 non-null  float64
#  9   opening_hours     16136 non-null  object
#  10  image_url         16125 non-null  object
#  11  radius            16136 non-null  int64
#  12  rating            14004 non-null  float64
#  13  reviews_nr        13602 non-null  float64
#  14  delivery_options  16136 non-null  object
#  15  promo             8777 non-null   object
# ...

# %% [markdown]
# So the dataset of 16136 rows of grab restaurants
# you can see from the count that there are empty values for each column

# %%
establishment_df.describe()
# Out:
#        delivery_cost           lat           lon        radius        rating  \
# count   16085.000000  16136.000000  16136.000000  16136.000000  14004.000000
# mean      984.926640      1.338491    103.843448   6871.493183      4.238346
# std       656.544752      0.045269      0.062123   6170.013565      0.619217
# min       199.000000      1.230454    103.625677    578.000000     -1.000000
# 25%       450.000000      1.304839    103.806196   4999.000000      4.000000
# 50%       680.000000      1.332154    103.846004   5000.000000      4.300000
# 75%      1610.000000      1.362576    103.885674   5000.000000      4.600000
# max     14000.000000      1.469011    103.997253  25000.000000      5.000000
#
#          reviews_nr  delivery_time
# count  13602.000000   15953.000000
# mean     343.591604      37.552811
# std      846.893054      15.728705
# min        1.000000      15.000000
# 25%       16.000000      28.000000
# 50%       74.000000      34.000000
# ...

# %% [markdown]
# As total rows should be 16136 you can deduce that are null values in delivery_cost, rating, reviews_nr and delivery time.
#
# I am concern on certain columns:</p>
# **name** </p>
# **cuisine** </p>
# **delivery_cost** </p>
# **delivery_time** </p>
#
# The rest of the columns is not that important because we might be dropping the columns or columns like reviews are allowed to be empty.

# %% [markdown]
# ### Next I want to see the distinct value of each columns to understand the columns better
#
# ![image-2.png](attachment:image-2.png)

# %%
#unique values of address
print(f"These are the unique values of loc_type column {establishment_df['name'].unique()}\n")

#unique values of address
print(f"These are the unique values of loc_type column {establishment_df['address'].unique()}\n")

#unique of loc_type 2 types food mart
print(f"These are the unique values of loc_type column {establishment_df['loc_type'].unique()}\n")

#2 type grab, merchant
print(f"These are the unique values of loc_type column {establishment_df['delivery_by'].unique()}\n")

# understanding cuisine column values
print(f"These are the unique values of loc_type column {establishment_df['cuisine'].unique()}\n")

# understanding delivery_options column values
print(f"These are the unique values of loc_type column {establishment_df['delivery_options'].unique()}\n")
# Out:
# These are the unique values of loc_type column ['Texas Chicken' 'Subway' 'LiHO Tea' ... 'Minjiangkueh'
#  'The Modern Izakaya by Tatsu' 'Zam Zam Indian Special Food']
#
# These are the unique values of loc_type column ['Texas Chicken - VivoCity' 'Subway - Vivocity' 'LiHO Tea - Vivo City' ...
#  'Raj Restaurant - SOHO @ Farrer'
#  'Albismi Indian Muslim Food - Woodlands Road'
#  'Zam Zam Indian Special Food - Yishun Industrial Park A']
#
# These are the unique values of loc_type column ['FOOD' 'MART']
#
# These are the unique values of loc_type column ['GRAB' 'MERCHANT']
#
# These are the unique values of loc_type column ['["Western", "Fast Food", "Halal", "Chicken", "Beverages"]'
#  '["Healthy", "Sandwiches", "Fast Food", "Halal", "Western"]'
#  '["Same Prices In-Store", "Beverages", "Local", "Bubble Tea"]' ...
#  '["Chicken", "Korean", "Fried Chicken"]'
#  '["Asian", "Bakery & Cake", "Breakfast & Brunch", "Singaporean"]'
#  '["Japanese", "Noodles", "Grill"]']
#
# ...

# %% [markdown]
# ### Investigating the null values
#
# **name** </p>
# **cuisine** </p>
# **delivery_cost** </p>
# **delivery_time** </p>

# %% [markdown]
# #### name column
# First is the name column as the expected count is 16136 but only 16130 is shown there should be 6 null values.</p>
# As you can see below are 6 stores where the name is null and shows most are test stores, probably that this are stores that was given as trial but did not convert to convert to GRAB stores.
#
# Conclusion to drop this 6 stores

# %%
establishment_df[establishment_df['name'].isna()]
# Out:
#              id_source name                                          address  \
# 628   4-CZDJJTWFC8BAAN  NaN                                   [TEST] - A-One
# 631   4-C2T2GYAJBEVFJN  NaN                                [Test] Fish & Co.
# 688   4-CZLVCKMHNYTXNX  NaN                               [Test] Shake Shack
# 692   4-CZKKR7K2JJ22NT  NaN  [Test] The Coffee Bean & Tea Leaf - KK Hospital
# 702   4-CYNANF42AEVAVA  NaN                        CBTL Test Store - Classic
# 1031  4-CZEXEPEWN6KKEN  NaN               FOODQA-BJ_SG's Sea Resto GKMM Mart
#
#         country                             cuisine currency  delivery_cost  \
# 628   Singapore  ["Kids Friendly", "Comfort Foods"]      SGD          560.0
# 631   Singapore                    ["Fish & Chips"]      SGD          610.0
# 688   Singapore  ["Burger", "Fast Food", "Western"]      SGD          560.0
# 692   Singapore                    ["Coffee & Tea"]      SGD          560.0
# ...

# %% [markdown]
# #### Cuisine column null values
# HAPPY THAI kitchen in clementi i have researched that it is thai restaurant so in cuisine put as thai
# https://www.google.com/search?hl=en-SG&gl=sg&q=431+Clementi+Ave+3,+%2301-296+Happy+Thai+Kitchen,+Singapore+120431&ludocid=9550498111253404072&lsig=AB86z5XMdpT1YVyvduw5eaJZY3L5&hl=en&gl=SG
# </p>
# RELAX BAR, have to opdate the cuisine with beverages, korean based on their fb page

# %%
establishment_df[establishment_df['cuisine'].isna()]
# Out:
#               id_source                name  \
# 2473   4-CZB3EYJJMEUBAX  HAPPY THAI KITCHEN
# 15049  4-C2EVG4BDGEVTG6           Relax Bar
#
#                                   address    country cuisine currency  \
# 2473                   HAPPY THAI KITCHEN  Singapore     NaN      SGD
# 15049  Relax Bar - The Punggol Settlement  Singapore     NaN      SGD
#
#        delivery_cost       lat         lon  \
# 2473          1890.0  1.303437  103.765536
# 15049         1900.0  1.420844  103.912429
#
#                                            opening_hours  \
# 2473   {"displayedHours": "Closed", "sun": "04:00-04:...
# 15049  {"displayedHours": "Closed", "sun": "15:00-22:...
#
#                                                image_url  radius  rating  \
# 2473   https://d1sag4ddilekf6.cloudfront.net/compress...    5000     4.1
# 15049  https://d1sag4ddilekf6.cloudfront.net/compress...    5000     5.0
#
#        reviews_nr   delivery_options  \
# 2473        102.0  DELIVERY_TAKEAWAY
# ...

# %% [markdown]
# #### delivery_cost column
#
# For delivey_cost column there are insufficient information on why the delivery cost is non-existent and therefore we will leave it for now
#
# #### delivery_time column
#
# as the delivery time has other relevant columns we cannot dropt this columns as there are insufficient information

# %%
establishment_df[establishment_df['delivery_cost'].isna()].head(3)
# Out:
#             id_source            name  \
# 623  4-CZDWKEXJV7EYNN         Dosirak
# 647  4-C2MTV33CJZLUSE          Lister
# 893  4-CZKKEBUFAFKGCX  The Grocery Co
#
#                                                address    country  \
# 623             Dosirak - Downtown Gallery - Catering   Singapore
# 647                              Lister - Tradehub 21   Singapore
# 893  The Grocery Co - By DKSH - Jalan Buroh (Next D...  Singapore
#
#                                                cuisine currency  \
# 623                  ["Healthy", "Korean", "Catering"]      SGD
# 647  ["Health & Wellness", "Mart", "Local", "Wellne...      SGD
# 893      ["Mart", "Groceries", "Local", "Convenience"]      SGD
#
#      delivery_cost       lat         lon  \
# 623            NaN  1.276788  103.848262
# 647            NaN  1.328091  103.752165
# 893            NaN  1.317135  103.715203
#
#                                          opening_hours  \
# ...

# %%
establishment_df[establishment_df['delivery_time'].isna()].head(3)
# Out:
#             id_source                      name  \
# 614  4-CZCVT4KHVB2UNJ  Rasel Catering Singapore
# 699  4-C2KKJ2LAN2L3GN             D'Yoma Coffee
# 889  4-C2JGV3WCLJE2N6          Boxgreen x Juicy
#
#                                                address    country  \
# 614  Rasel Catering Singapore - Pandan Loop - Cater...  Singapore
# 699                  D'Yoma Coffee - Clementi Meadows   Singapore
# 889  Boxgreen x Juicy - Kian Teck Road [Islandwide ...  Singapore
#
#                                                cuisine currency  \
# 614    ["Asian", "International", "Catering", "Halal"]      SGD
# 699  ["Coffee & Tea", "Mart", "Roasted Coffee Beans...      SGD
# 889                    ["Beverages", "Snacks", "Mart"]      SGD
#
#      delivery_cost       lat         lon  \
# 614         2000.0  1.312232  103.750662
# 699          300.0  1.321470  103.765870
# 889         1200.0  1.328727  103.688334
#
#                                          opening_hours  \
# ...

# %% [markdown]
# filling up the null values for cuisine column

# %%
# Change the 'cuisine' column of the row at index 2473 to ["thai"]
establishment_df.loc[2473, 'cuisine'] = ['"thai"']

establishment_df.iloc[[2473,2475]]
# Out:
#              id_source                name                         address  \
# 2473  4-CZB3EYJJMEUBAX  HAPPY THAI KITCHEN              HAPPY THAI KITCHEN
# 2475  4-CYXWVYMENBETTT          Ho Kee Pau  Ho Kee Pau - The Clementi Mall
#
#         country                              cuisine currency  delivery_cost  \
# 2473  Singapore                             ["thai"]      SGD         1890.0
# 2475  Singapore  ["Beverages", "Chinese", "Dim Sum"]      SGD          610.0
#
#            lat         lon                                      opening_hours  \
# 2473  1.303437  103.765536  {"displayedHours": "Closed", "sun": "04:00-04:...
# 2475  1.315169  103.764573  {"open": true, "displayedHours": "12:00-19:30"...
#
#                                               image_url  radius  rating  \
# 2473  https://d1sag4ddilekf6.cloudfront.net/compress...    5000     4.1
# 2475  https://d1sag4ddilekf6.cloudfront.net/compress...    5000     3.9
#
#       reviews_nr   delivery_options  \
# ...

# %%
# Change the 'cuisine' column of the row at index 15049 to ["beverages", "korean"]
establishment_df.at[15049, 'cuisine'] = ['"beverages"', '"korean"']

establishment_df.iloc[[15049,15050]]
# Out:
#               id_source         name                             address  \
# 15049  4-C2EVG4BDGEVTG6    Relax Bar  Relax Bar - The Punggol Settlement
# 15050         SGDD11996  Wang Caifan           Wang Caifan - Sumang Walk
#
#          country                  cuisine currency  delivery_cost       lat  \
# 15049  Singapore  ["beverages", "korean"]      SGD         1900.0  1.420844
# 15050  Singapore     ["Chinese", "Local"]      SGD         1740.0  1.403210
#
#               lon                                      opening_hours  \
# 15049  103.912429  {"displayedHours": "Closed", "sun": "15:00-22:...
# 15050  103.895825  {"displayedHours": "Closed", "sun": "10:30-20:...
#
#                                                image_url  radius  rating  \
# 15049  https://d1sag4ddilekf6.cloudfront.net/compress...    5000     5.0
# 15050  https://d1sag4ddilekf6.cloudfront.net/compress...    5000     3.9
#
#        reviews_nr   delivery_options                            promo  \
# ...

# %%
establishment_df[establishment_df['cuisine'].isna()]
# Out:
# Empty DataFrame
# Columns: [id_source, name, address, country, cuisine, currency, delivery_cost, lat, lon, opening_hours, image_url, radius, rating, reviews_nr, delivery_options, promo, loc_type, delivery_by, delivery_time]
# Index: []

# %%
establishment_df[establishment_df['cuisine'].isna()]
# Out:
# Empty DataFrame
# Columns: [id_source, name, address, country, cuisine, currency, delivery_cost, lat, lon, opening_hours, image_url, radius, rating, reviews_nr, delivery_options, promo, loc_type, delivery_by, delivery_time]
# Index: []

# %% [markdown]
# ### Creating the cuisine_df dataframe
#
# first we are going to replace the establishment_df['cuisine'] list rows from " into ' quote.
# Then we create a column for the eventual primary key called cus_id
# then we only have 3 columns in cuisine_df which is cuisine_id , id_source and cuisine

# %%
cuisine_df=establishment_df

#clearing ' due to aprostophe 's from cuisine_df['cuisine'] list
cuisine_df['cuisine']=cuisine_df['cuisine'].str.replace('\'',"")

#clearing " from cuisine_df['cuisine'] list
cuisine_df['cuisine']=cuisine_df['cuisine'].str.replace('"',"")

#clearing [,] from cuisine_df['cuisine'] list
cuisine_df['cuisine']=cuisine_df['cuisine'].str.replace('[',"")
cuisine_df['cuisine']=cuisine_df['cuisine'].str.replace(']',"")

# Add a primary key column
cuisine_df['cuisine_id'] = ['cus_' + str(i + 1) for i in range(len(cuisine_df))]

cuisine_df=cuisine_df[['cuisine_id','id_source','cuisine']]

#making all text in cuisine column to lowercase
cuisine_df.loc[:, 'cuisine']=cuisine_df['cuisine'].str.lower()

cuisine_df
# Out:
#       cuisine_id         id_source  \
# 0          cus_1         SGDD01085
# 1          cus_2  4-CYTDLPUJEP53N6
# 2          cus_3         SGDD05605
# 3          cus_4         SGDD07548
# 4          cus_5  4-CY2ZLZLTT2EDJ2
# ...          ...               ...
# 16131  cus_16132  4-CZNFTYKKVA3UN2
# 16132  cus_16133         SGDD01192
# 16133  cus_16134         SGDD00961
# 16134  cus_16135  4-C2AHJVATN7C2RE
# 16135  cus_16136  4-C2DXFEK2R6KJTJ
#
#                                                  cuisine
# 0          western, fast food, halal, chicken, beverages
# 1         healthy, sandwiches, fast food, halal, western
# 2      same prices in-store, beverages, local, bubble...
# 3             halal, chicken, fast food, burger, western
# 4                        japanese, ramen, noodles, asian
# ...                                                  ...
# 16131  asian, bakery & cake, breakfast & brunch, sing...
# 16132                           japanese, noodles, grill
# ...

# %% [markdown]
# null values found in cuisine, this we will fill it with thai for index 2473 and korean, beveragees for indx 15049

# %%
cuisine_df[cuisine_df['cuisine'].isna()]
# Out:
#       cuisine_id         id_source cuisine
# 2473    cus_2474  4-CZB3EYJJMEUBAX     NaN
# 15049  cus_15050  4-C2EVG4BDGEVTG6     NaN

# %%
# filling up null values with relevant values
cuisine_df.at[2473, 'cuisine'] = 'thai'
cuisine_df.at[15049, 'cuisine'] = 'beverages, korean'

#check row 2473
#cuisine_df.iloc[[2473,2474]]
cuisine_df.iloc[[15049]]

#check if there are any more nulls in cuisine column
#cuisine_df[cuisine_df['cuisine'].isna()]

#cuisine_df
# Out:
#       cuisine_id         id_source            cuisine
# 15049  cus_15050  4-C2EVG4BDGEVTG6  beverages, korean

# %%
# Sort the values within each string alphabetically
cuisine_df['cuisine'] = cuisine_df['cuisine'].apply(lambda x: ', '.join(sorted(x.split(', '))))


cuisine_df
# Out:
# C:\Users\T470\AppData\Local\Temp\ipykernel_24800\3522236522.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cuisine_df['cuisine'] = cuisine_df['cuisine'].apply(lambda x: ', '.join(sorted(x.split(', '))))
#       cuisine_id         id_source  \
# 0          cus_1         SGDD01085
# 1          cus_2  4-CYTDLPUJEP53N6
# 2          cus_3         SGDD05605
# 3          cus_4         SGDD07548
# 4          cus_5  4-CY2ZLZLTT2EDJ2
# ...          ...               ...
# 16131  cus_16132  4-CZNFTYKKVA3UN2
# 16132  cus_16133         SGDD01192
# 16133  cus_16134         SGDD00961
# 16134  cus_16135  4-C2AHJVATN7C2RE
# 16135  cus_16136  4-C2DXFEK2R6KJTJ
#
#                                                  cuisine
# ...

# %%
# Split the 'cuisine' column by comma and expand into separate columns
cuisines_split = cuisine_df['cuisine'].str.split(', ', expand=True)

# Rename the new columns
cuisines_split.columns = [f'cuisine_{i+1}' for i in range(cuisines_split.shape[1])]

# Concatenate the new columns with the original DataFrame and drop the old cuisine column
cuisine_df = pd.concat([cuisine_df.drop(columns=['cuisine']), cuisines_split], axis=1)

cuisine_df
# Out:
#       cuisine_id         id_source  cuisine_1      cuisine_2  \
# 0          cus_1         SGDD01085  beverages        chicken
# 1          cus_2  4-CYTDLPUJEP53N6  fast food          halal
# 2          cus_3         SGDD05605  beverages     bubble tea
# 3          cus_4         SGDD07548     burger        chicken
# 4          cus_5  4-CY2ZLZLTT2EDJ2      asian       japanese
# ...          ...               ...        ...            ...
# 16131  cus_16132  4-CZNFTYKKVA3UN2      asian  bakery & cake
# 16132  cus_16133         SGDD01192      grill       japanese
# 16133  cus_16134         SGDD00961    dessert         indian
# 16134  cus_16135  4-C2AHJVATN7C2RE     indian           None
# 16135  cus_16136  4-C2DXFEK2R6KJTJ     indian           None
#
#                 cuisine_3             cuisine_4 cuisine_5
# 0               fast food                 halal   western
# 1                 healthy            sandwiches   western
# ...

# %% [markdown]
# ### Checking commonality in the grouping to see if we can clean further

# %%
#check commonlity

# Specify selected columns
selected_columns = ['cuisine_1', 'cuisine_2', 'cuisine_3', 'cuisine_4', 'cuisine_5']
# Apply value_counts function to each column and calculate commonality
commonality = cuisine_df[selected_columns].apply(pd.Series.value_counts, axis=1).fillna(0).sum().astype(int)

print(commonality)
# Out:
# 1 michelin star         11
# 2 michelin stars         1
# accessories              2
# alcohol                464
# alcoholic beverages      8
#                       ...
# wine                    67
# wings                    7
# wok                      7
# wraps                   12
# yogurt                  26
# Length: 293, dtype: int32

# %%
# further cleaning to change 2 michelin star to 1 michelin star

# Find rows where any of the selected columns contain '2 michelin stars'
rows_to_replace = cuisine_df[selected_columns].apply(lambda x: x.str.contains('2 michelin stars')).any(axis=1)
# Replace '2 michelin stars' with 'michelin star'
cuisine_df.loc[rows_to_replace, selected_columns] = cuisine_df[selected_columns].replace('2 michelin stars', '1 michelin star')

# further cleaning to change 1 michelin star to michelin star
rows_to_replace = cuisine_df[selected_columns].apply(lambda x: x.str.contains('1 michelin star')).any(axis=1)
# Replace '2 michelin stars' with 'michelin star'
cuisine_df.loc[rows_to_replace, selected_columns] = cuisine_df[selected_columns].replace('1 michelin star', 'michelin star')

# further cleaning to change michelin guide to michelin star
rows_to_replace = cuisine_df[selected_columns].apply(lambda x: x.str.contains('michelin guide')).any(axis=1)
# Replace '2 michelin stars' with 'michelin star'
cuisine_df.loc[rows_to_replace, selected_columns] = cuisine_df[selected_columns].replace('michelin guide', 'michelin star')

#further cleanin alcoholic beverages to just alcohol
rows_to_replace = cuisine_df[selected_columns].apply(lambda x: x.str.contains('alcoholic beverages')).any(axis=1)
# Replace 'alcoholic beverages' with 'alcohol'
cuisine_df.loc[rows_to_replace, selected_columns] = cuisine_df[selected_columns].replace('alcoholic beverages', 'alcohol')

#to group and count each unique value of cuisine column
# Apply value_counts function to each column and calculate commonality
commonality = cuisine_df[selected_columns].apply(pd.Series.value_counts, axis=1).fillna(0).sum().astype(int)

# Sort commonality counts from biggest to smallest
commonality_sort_values = commonality.sort_values(ascending=False)

# Sort commonality counts alphabetically
commonality_sort_alpha = commonality.sort_index()

# %%
cuisine_df
# Out:
#       cuisine_id         id_source  cuisine_1      cuisine_2  \
# 0          cus_1         SGDD01085  beverages        chicken
# 1          cus_2  4-CYTDLPUJEP53N6  fast food          halal
# 2          cus_3         SGDD05605  beverages     bubble tea
# 3          cus_4         SGDD07548     burger        chicken
# 4          cus_5  4-CY2ZLZLTT2EDJ2      asian       japanese
# ...          ...               ...        ...            ...
# 16131  cus_16132  4-CZNFTYKKVA3UN2      asian  bakery & cake
# 16132  cus_16133         SGDD01192      grill       japanese
# 16133  cus_16134         SGDD00961    dessert         indian
# 16134  cus_16135  4-C2AHJVATN7C2RE     indian           None
# 16135  cus_16136  4-C2DXFEK2R6KJTJ     indian           None
#
#                 cuisine_3             cuisine_4 cuisine_5
# 0               fast food                 halal   western
# 1                 healthy            sandwiches   western
# ...

# %%
print(commonality_sort_values.tail(10))
# Out:
# footwear                    1
# coconut                     1
# specialty store             1
# pets                        1
# sports equipment            1
# comfort foods               1
# pet care & accessories      1
# lebanese                    1
# stewed pork knuckle rice    1
# beverage                    1
# dtype: int32

# %% [markdown]
# ### adding to a Database

# %%
# !pip install sqlalchemy
# !pip install psycopg2
# Out:
# ...
# [notice] A new release of pip is available: 23.3.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
# [notice] A new release of pip is available: 23.3.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from sqlalchemy import create_engine
username='postgres'
password = 'admin'
hostname = 'localhost'
port = 5432
database = 'grab_db'

db_url = f'postgresql://{username}:{password}@{hostname}:{port}/{database}'

#create a connection to the database
#engine = create_engine('postgresql://postgres:admin@localhost:5432/grab_db')
engine = create_engine(db_url)


# Create a new cuisine table
commands = ('''Create TABLE IF NOT EXISTS cuisine_tbl(cuisine_id VARCHAR PRIMARY KEY,
                                                id_source VARCHAR,
                                                streaming_service VARCHAR,
                                                cuisine_1 VARCHAR,
                                                cuisine_2 VARCHAR,
                                                cuisine_3 VARCHAR,
                                                cuisine_4 VARCHAR,
                                                cuisine_5 VARCHAR,
                                                );''')

# Step 9: Copy the data to the PostgreSQL table
cuisine_df.to_sql('cuisine_tbl', engine, if_exists='replace', index=False)
# Out:
# 136

# %% [markdown]
# #### testing code to upload to postgresql database in elephant SQL

# %%
# from sqlalchemy import create_engine
# #elephantSQL a postgresql SAS version - 

# # Replace these values with your ElephantSQL credentials and database URL
# username = 'dgvjfhxu'
# password = 'eCegJ_4NVogXXa7FzQujcfViOczo9gbf'
# hostname = 'hansken.db.elephantsql.com'
# database = 'dgvjfhxu'

# # Construct the database URL
# db_url = f'postgresql://{username}:{password}@{hostname}/{database}'

# engine = create_engine(db_url)

# # Replace df with your DataFrame
# cuisine_df.to_sql('cuisine_tbl', engine, if_exists='replace', index=False)


# #successful update but did not try further as the relationship not created

# %% [markdown]
# ## Analysis: from Database

# %%
import psycopg2

# Database connection parameters
DB_NAME = 'grab_db'
DB_USER = 'postgres'
DB_PASSWORD = 'admin'
DB_HOST = 'localhost'
DB_PORT = '5432'

# Connect to the PostgreSQL database
conn = psycopg2.connect(
    dbname=DB_NAME,
    user=DB_USER,
    password=DB_PASSWORD,
    host=DB_HOST,
    port=DB_PORT
)

# SQL query to select data from a table
query = "SELECT * FROM cuisine_tbl"

# Execute the query and fetch the results
cursor = conn.cursor()
cursor.execute(query)

# Fetch all rows from the result set
rows = cursor.fetchall()

# Get the column names from the cursor description
columns = [desc[0] for desc in cursor.description]

# Create a Pandas DataFrame from the fetched data
cuisine_table = pd.DataFrame(rows, columns=columns)

# Close the cursor and connection
cursor.close()
conn.close()

# Now you can perform analysis on the DataFrame (df)
print(cuisine_table.head())  # Print the first few rows of the DataFrame
# Out:
#   cuisine_id         id_source  cuisine_1   cuisine_2  cuisine_3  \
# 0      cus_1         SGDD01085  beverages     chicken  fast food
# 1      cus_2  4-CYTDLPUJEP53N6  fast food       halal    healthy
# 2      cus_3         SGDD05605  beverages  bubble tea      local
# 3      cus_4         SGDD07548     burger     chicken  fast food
# 4      cus_5  4-CY2ZLZLTT2EDJ2      asian    japanese    noodles
#
#               cuisine_4 cuisine_5
# 0                 halal   western
# 1            sandwiches   western
# 2  same prices in-store      None
# 3                 halal   western
# 4                 ramen      None

# %% [markdown]
# ## Top 10 establishment categories

# %%
# Specify selected columns
selected_columns = ['cuisine_1', 'cuisine_2', 'cuisine_3', 'cuisine_4', 'cuisine_5']

# Apply value_counts function to each column and calculate commonality
cuisine_category = cuisine_table[selected_columns].apply(pd.Series.value_counts, axis=1).fillna(0).sum().astype(int)

# Sort commonality counts from biggest to smallest
cuisine_category_sort_values = cuisine_category.sort_values(ascending=False)

print(cuisine_category_sort_values.head(10))
# Out:
# asian        4465
# local        4332
# chinese      3889
# western      2498
# noodles      2126
# beverages    2036
# mart         2027
# chicken      1950
# halal        1612
# seafood      1519
# dtype: int32

# %%
from matplotlib import pyplot as plt
from sqlalchemy import create_engine

username='postgres'
password = 'admin'
hostname = 'localhost'
port = 5432
database = 'grab_db'

db_url = f'postgresql://{username}:{password}@{hostname}:{port}/{database}'


# Connect to PostgreSQL database using SQLAlchemy
engine = create_engine(db_url)
# Query the data from the table
query = "SELECT cuisine_1, cuisine_2, cuisine_3, cuisine_4, cuisine_5 FROM cuisine_tbl"
cuisine_category = pd.read_sql(query, engine)

# Reshape the DataFrame to have a single column for cuisine
cuisine_columns = ['cuisine_1', 'cuisine_2', 'cuisine_3', 'cuisine_4', 'cuisine_5']
cuisine_category = pd.melt(cuisine_category, value_vars=cuisine_columns, var_name='cuisine')

# Count the occurrences of each cuisine
cuisine_category = cuisine_category['value'].value_counts().head(10)

# Plot a bar chart
plt.figure(figsize=(10, 6))
cuisine_category.plot(kind='bar')
plt.title('Cuisine Distribution')
plt.xlabel('Cuisine')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
