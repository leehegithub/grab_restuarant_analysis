# %%
import pandas as pd
grab_rest = pd.read_csv('C:/Users/Ros/Desktop/JDC/Grab_SG_Restaurants.csv')
grab_rest.head()
# Out:
#           id_source             name                     address    country  \
# 0         SGDD01085    Texas Chicken    Texas Chicken - VivoCity  Singapore
# 1  4-CYTDLPUJEP53N6           Subway           Subway - Vivocity  Singapore
# 2         SGDD05605         LiHO Tea        LiHO Tea - Vivo City  Singapore
# 3         SGDD07548         Wingstop         Wingstop - VivoCity  Singapore
# 4  4-CY2ZLZLTT2EDJ2  Le Shrimp Ramen  Le Shrimp Ramen - Vivocity  Singapore
#
#                                              cuisine currency  delivery_cost  \
# 0  ["Western", "Fast Food", "Halal", "Chicken", "...      SGD          570.0
# 1  ["Healthy", "Sandwiches", "Fast Food", "Halal"...      SGD          570.0
# 2  ["Same Prices In-Store", "Beverages", "Local",...      SGD          560.0
# 3  ["Halal", "Chicken", "Fast Food", "Burger", "W...      SGD          560.0
# 4          ["Japanese", "Ramen", "Noodles", "Asian"]      SGD          570.0
#
#         lat         lon                                      opening_hours  \
# 0  1.264792  103.822103  {"open": true, "displayedHours": "10:30-21:30"...
# 1  1.264741  103.822072  {"open": true, "displayedHours": "12:00-19:00"...
# 2  1.264309  103.821369  {"open": true, "displayedHours": "11:30-20:45"...
# 3  1.263527  103.821712  {"open": true, "displayedHours": "11:00-21:00"...
# 4  1.264810  103.822554  {"open": true, "displayedHours": "10:30-21:00"...
#
#                                            image_url  radius  rating  \
# 0  https://d1sag4ddilekf6.cloudfront.net/compress...    5000     3.8
# 1  https://d1sag4ddilekf6.cloudfront.net/compress...    3000     4.2
# 2  https://d1sag4ddilekf6.cloudfront.net/compress...    5000     4.5
# 3  https://d1sag4ddilekf6.cloudfront.net/compress...    5000     4.4
# 4  https://d1sag4ddilekf6.cloudfront.net/compress...    5000     4.6
#
#    reviews_nr   delivery_options  \
# 0      1591.0      ONLY_DELIVERY
# 1       197.0      ONLY_DELIVERY
# 2       353.0  DELIVERY_TAKEAWAY
# 3      1391.0      ONLY_DELIVERY
# 4       309.0  DELIVERY_TAKEAWAY
#
#                                                promo loc_type delivery_by  \
# 0  Use 'TEATIME' for FREE delivery between 3PM to...     FOOD        GRAB
# 1  Use 'TEATIME' for FREE delivery between 3PM to...     FOOD        GRAB
# 2  Use 'TEATIME' for FREE delivery between 3PM to...     FOOD        GRAB
# 3  Use 'TEATIME' for FREE delivery between 3PM to...     FOOD        GRAB
# 4  Use 'TEATIME' for FREE delivery between 3PM to...     FOOD        GRAB
#
#    delivery_time
# 0           43.0
# 1           42.0
# 2           41.0
# 3           45.0
# 4           44.0

# %%
grab_rest.columns
# Out:
# Index(['id_source', 'name', 'address', 'country', 'cuisine', 'currency',
#        'delivery_cost', 'lat', 'lon', 'opening_hours', 'image_url', 'radius',
#        'rating', 'reviews_nr', 'delivery_options', 'promo', 'loc_type',
#        'delivery_by', 'delivery_time'],
#       dtype='object')

# %%
cuisine_table =grab_rest[['id_source','name', 'cuisine']].drop_duplicates().reset_index(drop=True)

cuisine_table
# Out:
#               id_source                         name  \
# 0             SGDD01085                Texas Chicken
# 1      4-CYTDLPUJEP53N6                       Subway
# 2             SGDD05605                     LiHO Tea
# 3             SGDD07548                     Wingstop
# 4      4-CY2ZLZLTT2EDJ2              Le Shrimp Ramen
# ...                 ...                          ...
# 16131  4-CZNFTYKKVA3UN2                 Minjiangkueh
# 16132         SGDD01192  The Modern Izakaya by Tatsu
# 16133         SGDD00961               Raj Restaurant
# 16134  4-C2AHJVATN7C2RE   Albismi Indian Muslim Food
# 16135  4-C2DXFEK2R6KJTJ  Zam Zam Indian Special Food
#
#                                                  cuisine
# 0      ["Western", "Fast Food", "Halal", "Chicken", "...
# 1      ["Healthy", "Sandwiches", "Fast Food", "Halal"...
# 2      ["Same Prices In-Store", "Beverages", "Local",...
# 3      ["Halal", "Chicken", "Fast Food", "Burger", "W...
# 4              ["Japanese", "Ramen", "Noodles", "Asian"]
# ...                                                  ...
# 16131  ["Asian", "Bakery & Cake", "Breakfast & Brunch...
# 16132                   ["Japanese", "Noodles", "Grill"]
# 16133                ["Indian", "Dessert", "Vegetarian"]
# 16134                                         ["Indian"]
# 16135                                         ["Indian"]
#
# [16136 rows x 3 columns]

# %%
delivery = grab_rest[['id_source','delivery_cost','radius','delivery_options','promo']].drop_duplicates().reset_index(drop=True)
delivery
# Out:
#               id_source  delivery_cost  radius          delivery_options  \
# 0             SGDD01085          570.0    5000             ONLY_DELIVERY
# 1      4-CYTDLPUJEP53N6          570.0    3000             ONLY_DELIVERY
# 2             SGDD05605          560.0    5000         DELIVERY_TAKEAWAY
# 3             SGDD07548          560.0    5000             ONLY_DELIVERY
# 4      4-CY2ZLZLTT2EDJ2          570.0    5000         DELIVERY_TAKEAWAY
# ...                 ...            ...     ...                       ...
# 16131  4-CZNFTYKKVA3UN2            NaN    5000         DELIVERY_TAKEAWAY
# 16132         SGDD01192            NaN    3000         DELIVERY_TAKEAWAY
# 16133         SGDD00961          560.0    3000  DELIVERY_TAKEAWAY_DINEIN
# 16134  4-C2AHJVATN7C2RE            NaN    5000         DELIVERY_TAKEAWAY
# 16135  4-C2DXFEK2R6KJTJ            NaN    5000         DELIVERY_TAKEAWAY
#
#                                                    promo
# 0      Use 'TEATIME' for FREE delivery between 3PM to...
# 1      Use 'TEATIME' for FREE delivery between 3PM to...
# 2      Use 'TEATIME' for FREE delivery between 3PM to...
# 3      Use 'TEATIME' for FREE delivery between 3PM to...
# 4      Use 'TEATIME' for FREE delivery between 3PM to...
# ...                                                  ...
# 16131                                                NaN
# 16132                                                NaN
# 16133                                                NaN
# 16134                                                NaN
# 16135  Use 'TEATIME' for FREE delivery between 3PM to...
#
# [16136 rows x 5 columns]

# %%
#Details of delivery_df:(ROSNI)
#id_source,delivery_cost, radius, delivery_options, promo 
delivery = grab_rest[['id_source','delivery_cost','radius','delivery_options','promo']]
delivery
#this is the delivery table with rows containing NaN values under promo column
# Out:
#               id_source  delivery_cost  radius          delivery_options  \
# 0             SGDD01085          570.0    5000             ONLY_DELIVERY
# 1      4-CYTDLPUJEP53N6          570.0    3000             ONLY_DELIVERY
# 2             SGDD05605          560.0    5000         DELIVERY_TAKEAWAY
# 3             SGDD07548          560.0    5000             ONLY_DELIVERY
# 4      4-CY2ZLZLTT2EDJ2          570.0    5000         DELIVERY_TAKEAWAY
# ...                 ...            ...     ...                       ...
# 16131  4-CZNFTYKKVA3UN2            NaN    5000         DELIVERY_TAKEAWAY
# 16132         SGDD01192            NaN    3000         DELIVERY_TAKEAWAY
# 16133         SGDD00961          560.0    3000  DELIVERY_TAKEAWAY_DINEIN
# 16134  4-C2AHJVATN7C2RE            NaN    5000         DELIVERY_TAKEAWAY
# 16135  4-C2DXFEK2R6KJTJ            NaN    5000         DELIVERY_TAKEAWAY
#
#                                                    promo
# 0      Use 'TEATIME' for FREE delivery between 3PM to...
# 1      Use 'TEATIME' for FREE delivery between 3PM to...
# 2      Use 'TEATIME' for FREE delivery between 3PM to...
# 3      Use 'TEATIME' for FREE delivery between 3PM to...
# 4      Use 'TEATIME' for FREE delivery between 3PM to...
# ...                                                  ...
# 16131                                                NaN
# 16132                                                NaN
# 16133                                                NaN
# 16134                                                NaN
# 16135  Use 'TEATIME' for FREE delivery between 3PM to...
#
# [16136 rows x 5 columns]

# %%
#listing the name of columns in delivery data frame
delivery.columns
# Out:
# Index(['id_source', 'delivery_cost', 'radius', 'delivery_options', 'promo'], dtype='object')

# %%
delivery.describe()
# Out:
#        delivery_cost        radius
# count   16085.000000  16136.000000
# mean      984.926640   6871.493183
# std       656.544752   6170.013565
# min       199.000000    578.000000
# 25%       450.000000   4999.000000
# 50%       680.000000   5000.000000
# 75%      1610.000000   5000.000000
# max     14000.000000  25000.000000

# %%
#copying all the contents of the table "delivery" and assigning the name "delivery_1" 
delivery_1=delivery.copy()
#to delivery_1 adding extra column named delivery_cost_sds with value =delivery_cost/100
delivery_1['delivery_cost_sds']=delivery['delivery_cost']/100
delivery_1
# Out:
#               id_source  delivery_cost  radius          delivery_options  \
# 0             SGDD01085          570.0    5000             ONLY_DELIVERY
# 1      4-CYTDLPUJEP53N6          570.0    3000             ONLY_DELIVERY
# 2             SGDD05605          560.0    5000         DELIVERY_TAKEAWAY
# 3             SGDD07548          560.0    5000             ONLY_DELIVERY
# 4      4-CY2ZLZLTT2EDJ2          570.0    5000         DELIVERY_TAKEAWAY
# ...                 ...            ...     ...                       ...
# 16131  4-CZNFTYKKVA3UN2            NaN    5000         DELIVERY_TAKEAWAY
# 16132         SGDD01192            NaN    3000         DELIVERY_TAKEAWAY
# 16133         SGDD00961          560.0    3000  DELIVERY_TAKEAWAY_DINEIN
# 16134  4-C2AHJVATN7C2RE            NaN    5000         DELIVERY_TAKEAWAY
# 16135  4-C2DXFEK2R6KJTJ            NaN    5000         DELIVERY_TAKEAWAY
#
#                                                    promo  delivery_cost_sds
# 0      Use 'TEATIME' for FREE delivery between 3PM to...                5.7
# 1      Use 'TEATIME' for FREE delivery between 3PM to...                5.7
# 2      Use 'TEATIME' for FREE delivery between 3PM to...                5.6
# 3      Use 'TEATIME' for FREE delivery between 3PM to...                5.6
# 4      Use 'TEATIME' for FREE delivery between 3PM to...                5.7
# ...                                                  ...                ...
# 16131                                                NaN                NaN
# 16132                                                NaN                NaN
# 16133                                                NaN                5.6
# 16134                                                NaN                NaN
# 16135  Use 'TEATIME' for FREE delivery between 3PM to...                NaN
#
# [16136 rows x 6 columns]

# %%
#selecting only the required columns to make a new df
delivery_df= delivery_1[['id_source','delivery_cost_sds','radius','delivery_options','promo']]
delivery_df
# Out:
#               id_source  delivery_cost_sds  radius          delivery_options  \
# 0             SGDD01085                5.7    5000             ONLY_DELIVERY
# 1      4-CYTDLPUJEP53N6                5.7    3000             ONLY_DELIVERY
# 2             SGDD05605                5.6    5000         DELIVERY_TAKEAWAY
# 3             SGDD07548                5.6    5000             ONLY_DELIVERY
# 4      4-CY2ZLZLTT2EDJ2                5.7    5000         DELIVERY_TAKEAWAY
# ...                 ...                ...     ...                       ...
# 16131  4-CZNFTYKKVA3UN2                NaN    5000         DELIVERY_TAKEAWAY
# 16132         SGDD01192                NaN    3000         DELIVERY_TAKEAWAY
# 16133         SGDD00961                5.6    3000  DELIVERY_TAKEAWAY_DINEIN
# 16134  4-C2AHJVATN7C2RE                NaN    5000         DELIVERY_TAKEAWAY
# 16135  4-C2DXFEK2R6KJTJ                NaN    5000         DELIVERY_TAKEAWAY
#
#                                                    promo
# 0      Use 'TEATIME' for FREE delivery between 3PM to...
# 1      Use 'TEATIME' for FREE delivery between 3PM to...
# 2      Use 'TEATIME' for FREE delivery between 3PM to...
# 3      Use 'TEATIME' for FREE delivery between 3PM to...
# 4      Use 'TEATIME' for FREE delivery between 3PM to...
# ...                                                  ...
# 16131                                                NaN
# 16132                                                NaN
# 16133                                                NaN
# 16134                                                NaN
# 16135  Use 'TEATIME' for FREE delivery between 3PM to...
#
# [16136 rows x 5 columns]

# %%
##delivery_promo = delivery_df['promo']
#delivery_promo['promo'].fillna ("No promotion", inplace= True)
# this code didnt work. so trying again
# for thiscode delivery_promo =delivery_df[['promo']]
#error message---C:\Users\Ros\AppData\Local\Temp\ipykernel_31724\4246233546.py:7: SettingWithCopyWarning: 
#A value is trying to be set on a copy of a slice from a DataFrame
#See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

#so i converted the delivery_promo table to df
delivery_promo = pd.DataFrame({'promo': delivery_df['promo']})

delivery_promo['promo'].fillna("No Promotion available", inplace= True)
delivery_promo
# Out:
#                                                    promo
# 0      Use 'TEATIME' for FREE delivery between 3PM to...
# 1      Use 'TEATIME' for FREE delivery between 3PM to...
# 2      Use 'TEATIME' for FREE delivery between 3PM to...
# 3      Use 'TEATIME' for FREE delivery between 3PM to...
# 4      Use 'TEATIME' for FREE delivery between 3PM to...
# ...                                                  ...
# 16131                             No Promotion available
# 16132                             No Promotion available
# 16133                             No Promotion available
# 16134                             No Promotion available
# 16135  Use 'TEATIME' for FREE delivery between 3PM to...
#
# [16136 rows x 1 columns]

# %% [markdown]
# delivery_promo = pd.DataFrame({'promo': delivery_promo['promo']}): This line creates a new df by calling the pd.DataFrame() constructor. It takes a dictionary as an argument, where the keys are the column names and the values are the column data. In this case, the dictionary has a single key-value pair where the key is 'promo' (the name of the column) and the value is delivery_promo['promo']. This extracts the 'promo' column from the existing DataFrame delivery_promo and creates a new DataFrame with a single column named 'promo'.Essentially, this line of code is used to isolate the 'promo' column from the original DataFrame and create a new DataFrame with just that column. This step may be necessary to perform operations specifically on the 'promo' column without affecting the original DataFrame structure

# %%
# Using .loc to modify the original DataFrame without triggering the warning
delivery_df.loc[:, 'promo'] = delivery_promo['promo']
delivery_df
# Out:
#               id_source  delivery_cost_sds  radius          delivery_options  \
# 0             SGDD01085                5.7    5000             ONLY_DELIVERY
# 1      4-CYTDLPUJEP53N6                5.7    3000             ONLY_DELIVERY
# 2             SGDD05605                5.6    5000         DELIVERY_TAKEAWAY
# 3             SGDD07548                5.6    5000             ONLY_DELIVERY
# 4      4-CY2ZLZLTT2EDJ2                5.7    5000         DELIVERY_TAKEAWAY
# ...                 ...                ...     ...                       ...
# 16131  4-CZNFTYKKVA3UN2                NaN    5000         DELIVERY_TAKEAWAY
# 16132         SGDD01192                NaN    3000         DELIVERY_TAKEAWAY
# 16133         SGDD00961                5.6    3000  DELIVERY_TAKEAWAY_DINEIN
# 16134  4-C2AHJVATN7C2RE                NaN    5000         DELIVERY_TAKEAWAY
# 16135  4-C2DXFEK2R6KJTJ                NaN    5000         DELIVERY_TAKEAWAY
#
#                                                    promo
# 0      Use 'TEATIME' for FREE delivery between 3PM to...
# 1      Use 'TEATIME' for FREE delivery between 3PM to...
# 2      Use 'TEATIME' for FREE delivery between 3PM to...
# 3      Use 'TEATIME' for FREE delivery between 3PM to...
# 4      Use 'TEATIME' for FREE delivery between 3PM to...
# ...                                                  ...
# 16131                             No Promotion available
# 16132                             No Promotion available
# 16133                             No Promotion available
# 16134                             No Promotion available
# 16135  Use 'TEATIME' for FREE delivery between 3PM to...
#
# [16136 rows x 5 columns]

# %%
delivery_df.info()
#from this we can understand the delivery_cost_sds column has 16085 non-null values.The remaining 51 ROWS are null or NaN
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16136 entries, 0 to 16135
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id_source          16136 non-null  object
#  1   delivery_cost_sds  16085 non-null  float64
#  2   radius             16136 non-null  int64
#  3   delivery_options   16136 non-null  object
#  4   promo              16136 non-null  object
# dtypes: float64(1), int64(1), object(3)
# memory usage: 630.4+ KB

# %%
# Using isna() method to create a boolean mask for NaN values
nan_mask = delivery_df.isna().any(axis=1)

# Filter the DataFrame to select rows with NaN values
rows_with_nan = delivery_df[nan_mask]

# Display the rows with NaN values
print(rows_with_nan)
# Out:
#               id_source  delivery_cost_sds  radius   delivery_options  \
# 623    4-CZDWKEXJV7EYNN                NaN   25000  DELIVERY_TAKEAWAY
# 647    4-C2MTV33CJZLUSE                NaN   25000      ONLY_DELIVERY
# 893    4-CZKKEBUFAFKGCX                NaN   10000      ONLY_DELIVERY
# 993    4-CZKKEBWJAJWCR2                NaN   15000      ONLY_DELIVERY
# 1009   4-C2KTCUK1PE22CT                NaN   25000      ONLY_DELIVERY
# 1039   4-C2NZNF6YLTL3PE                NaN   10000      ONLY_DELIVERY
# 1043   4-C2TVNK62ELN3KE                NaN   25000      ONLY_DELIVERY
# 1146   4-CZDWKEXCPB31RT                NaN   25000  DELIVERY_TAKEAWAY
# 2165   4-CZC2APLUCNTWN2                NaN    2500  DELIVERY_TAKEAWAY
# 2176   4-CZD3RK6TGUKJDE                NaN   25000  DELIVERY_TAKEAWAY
# 2232   4-C2T2JRLYLXWXR2                NaN    4000      ONLY_DELIVERY
# 3831   4-C2T2J62YNPNBGT                NaN   25000  DELIVERY_TAKEAWAY
# 4247   4-CZE1VPUUGGE1JT                NaN   25000  DELIVERY_TAKEAWAY
# 4284   4-C2L2A2JECA4ETN                NaN   25000      ONLY_DELIVERY
# 4374   4-C2LXKF61AF3ANN                NaN   25000      ONLY_DELIVERY
# 4394   4-C2L1UANXRFWUPA                NaN   25000      ONLY_DELIVERY
# 4412   4-C2JZGJ6WNXDGV6                NaN   25000      ONLY_DELIVERY
# 4453   4-C2BYCLLCLLKFRX                NaN   25000      ONLY_DELIVERY
# 4515   4-CZC1FBTGCJ33R6                NaN   20000  DELIVERY_TAKEAWAY
# 4823   4-C2DTPCNUFALHL6                NaN   25000      ONLY_DELIVERY
# 7814   4-CZATPBDFL6KXJ6                NaN   20000  DELIVERY_TAKEAWAY
# 8614   4-CZJHE7NWCEDCEE                NaN   25000      ONLY_DELIVERY
# 9380   4-CZC2DFVKJJCFGT                NaN   25000  DELIVERY_TAKEAWAY
# 9592   4-C2NCDBU1VZAGKA                NaN   25000      ONLY_DELIVERY
# 9597   4-CZJ3LTWJLAUYJJ                NaN   25000      ONLY_DELIVERY
# 9645   4-C2JYJYCER8NEUE                NaN   25000      ONLY_DELIVERY
# 9978   4-C2MZV2NWJ2EJVA                NaN   10000      ONLY_DELIVERY
# 10028  4-C2NFRCNZGE6HUE                NaN   25000      ONLY_DELIVERY
# 10179  4-C2EVEAXGL3CKT2                NaN   10000      ONLY_DELIVERY
# 11273  4-CZDYGFB3EX42AT                NaN   25000  DELIVERY_TAKEAWAY
# 14076  4-C2NYAYU1EPTCNJ                NaN   25000      ONLY_DELIVERY
# 15767  4-C2UGGBB1AA5TAX                NaN    3000  DELIVERY_TAKEAWAY
# 16112  4-C2NULJ6XEELYTJ                NaN    5000  DELIVERY_TAKEAWAY
# 16113  4-C2CAFBU3T24BGX                NaN    5000  DELIVERY_TAKEAWAY
# 16114  4-CZLXBGDCNRAFPA                NaN   10000      ONLY_DELIVERY
# 16116  4-C2UHTUVKJB51R2                NaN    2500      ONLY_DELIVERY
# 16118  4-CZNVVUUZJXDCR6                NaN    5000  DELIVERY_TAKEAWAY
# 16120  4-C2JWAKCFE7C2TJ                NaN    5000  DELIVERY_TAKEAWAY
# 16121  4-C2DKPANTSA51VE                NaN    5000  DELIVERY_TAKEAWAY
# 16122  4-C2NULJ6WCCCKLE                NaN    5000  DELIVERY_TAKEAWAY
# 16123  4-C2BVAKK1J7U3EX                NaN    5000      ONLY_DELIVERY
# 16124  4-C2MUAJN3UEWFJN                NaN   10000      ONLY_DELIVERY
# 16125  4-CYMUL4M3T2KGUE                NaN    5000  DELIVERY_TAKEAWAY
# 16126  4-CZEFR6AUNNXTLA                NaN    5000  DELIVERY_TAKEAWAY
# 16127  4-C2TVG3VEC752L2                NaN    5000  DELIVERY_TAKEAWAY
# 16129  4-CYVETVMAR7DVLX                NaN    5000  DELIVERY_TAKEAWAY
# 16130  4-C2MHKEVGRYXELT                NaN   10000      ONLY_DELIVERY
# 16131  4-CZNFTYKKVA3UN2                NaN    5000  DELIVERY_TAKEAWAY
# 16132         SGDD01192                NaN    3000  DELIVERY_TAKEAWAY
# 16134  4-C2AHJVATN7C2RE                NaN    5000  DELIVERY_TAKEAWAY
# 16135  4-C2DXFEK2R6KJTJ                NaN    5000  DELIVERY_TAKEAWAY
#
#                                                    promo
# 623                               No Promotion available
# 647    Enjoy 20% off min. spend $25 with promo code "...
# 893    Enjoy 20% off min. spend $25 with promo code "...
# 993                               No Promotion available
# 1009   Enjoy 20% off min. spend $25 with promo code "...
# 1039   Enjoy 20% off min. spend $25 with promo code "...
# 1043   50% off United Sports Double Shoot-Out Arcade ...
# 1146   Use "GRAB5313" to enjoy a $5 discount, min spe...
# 2165                              No Promotion available
# 2176                              No Promotion available
# 2232   S$10.00 off delivery fee with S$225.00 min. order
# 3831                              No Promotion available
# 4247                              No Promotion available
# 4284   Enjoy 20% off min. spend $25 with promo code "...
# 4374                              No Promotion available
# 4394                              No Promotion available
# 4412   Enjoy 20% off min. spend $25 with promo code "...
# 4453   Enjoy 20% off min. spend $25 with promo code "...
# 4515                              No Promotion available
# 4823                              No Promotion available
# 7814                              No Promotion available
# 8614   Enjoy 20% off min. spend $25 with promo code "...
# 9380     S$3.00 off delivery fee with S$30.00 min. order
# 9592                              No Promotion available
# 9597   Enjoy 20% off min. spend $25 with promo code "...
# 9645                              No Promotion available
# 9978   Enjoy 20% off min. spend $25 with promo code "...
# 10028  Enjoy 20% off min. spend $25 with promo code "...
# 10179                             No Promotion available
# 11273  Use 'TEATIME' for FREE delivery between 3PM to...
# 14076                             No Promotion available
# 15767                             No Promotion available
# 16112                             No Promotion available
# 16113                             No Promotion available
# 16114  Enjoy 20% off min. spend $25 with promo code "...
# 16116                             No Promotion available
# 16118                             No Promotion available
# 16120                             No Promotion available
# 16121  Use 'TEATIME' for FREE delivery between 3PM to...
# 16122                             No Promotion available
# 16123                             No Promotion available
# 16124  Enjoy 20% off min. spend $25 with promo code "...
# 16125                             No Promotion available
# 16126                             No Promotion available
# 16127                    20% off with S$30.00 min. order
# 16129                             No Promotion available
# 16130  Enjoy 20% off min. spend $25 with promo code "...
# 16131                             No Promotion available
# 16132                             No Promotion available
# 16134                             No Promotion available
# 16135  Use 'TEATIME' for FREE delivery between 3PM to...

# %%
rows_with_nan
# Out:
#               id_source  delivery_cost_sds  radius   delivery_options  \
# 623    4-CZDWKEXJV7EYNN                NaN   25000  DELIVERY_TAKEAWAY
# 647    4-C2MTV33CJZLUSE                NaN   25000      ONLY_DELIVERY
# 893    4-CZKKEBUFAFKGCX                NaN   10000      ONLY_DELIVERY
# 993    4-CZKKEBWJAJWCR2                NaN   15000      ONLY_DELIVERY
# 1009   4-C2KTCUK1PE22CT                NaN   25000      ONLY_DELIVERY
# 1039   4-C2NZNF6YLTL3PE                NaN   10000      ONLY_DELIVERY
# 1043   4-C2TVNK62ELN3KE                NaN   25000      ONLY_DELIVERY
# 1146   4-CZDWKEXCPB31RT                NaN   25000  DELIVERY_TAKEAWAY
# 2165   4-CZC2APLUCNTWN2                NaN    2500  DELIVERY_TAKEAWAY
# 2176   4-CZD3RK6TGUKJDE                NaN   25000  DELIVERY_TAKEAWAY
# 2232   4-C2T2JRLYLXWXR2                NaN    4000      ONLY_DELIVERY
# 3831   4-C2T2J62YNPNBGT                NaN   25000  DELIVERY_TAKEAWAY
# 4247   4-CZE1VPUUGGE1JT                NaN   25000  DELIVERY_TAKEAWAY
# 4284   4-C2L2A2JECA4ETN                NaN   25000      ONLY_DELIVERY
# 4374   4-C2LXKF61AF3ANN                NaN   25000      ONLY_DELIVERY
# 4394   4-C2L1UANXRFWUPA                NaN   25000      ONLY_DELIVERY
# 4412   4-C2JZGJ6WNXDGV6                NaN   25000      ONLY_DELIVERY
# 4453   4-C2BYCLLCLLKFRX                NaN   25000      ONLY_DELIVERY
# 4515   4-CZC1FBTGCJ33R6                NaN   20000  DELIVERY_TAKEAWAY
# 4823   4-C2DTPCNUFALHL6                NaN   25000      ONLY_DELIVERY
# 7814   4-CZATPBDFL6KXJ6                NaN   20000  DELIVERY_TAKEAWAY
# 8614   4-CZJHE7NWCEDCEE                NaN   25000      ONLY_DELIVERY
# 9380   4-CZC2DFVKJJCFGT                NaN   25000  DELIVERY_TAKEAWAY
# 9592   4-C2NCDBU1VZAGKA                NaN   25000      ONLY_DELIVERY
# 9597   4-CZJ3LTWJLAUYJJ                NaN   25000      ONLY_DELIVERY
# 9645   4-C2JYJYCER8NEUE                NaN   25000      ONLY_DELIVERY
# 9978   4-C2MZV2NWJ2EJVA                NaN   10000      ONLY_DELIVERY
# 10028  4-C2NFRCNZGE6HUE                NaN   25000      ONLY_DELIVERY
# 10179  4-C2EVEAXGL3CKT2                NaN   10000      ONLY_DELIVERY
# 11273  4-CZDYGFB3EX42AT                NaN   25000  DELIVERY_TAKEAWAY
# 14076  4-C2NYAYU1EPTCNJ                NaN   25000      ONLY_DELIVERY
# 15767  4-C2UGGBB1AA5TAX                NaN    3000  DELIVERY_TAKEAWAY
# 16112  4-C2NULJ6XEELYTJ                NaN    5000  DELIVERY_TAKEAWAY
# 16113  4-C2CAFBU3T24BGX                NaN    5000  DELIVERY_TAKEAWAY
# 16114  4-CZLXBGDCNRAFPA                NaN   10000      ONLY_DELIVERY
# 16116  4-C2UHTUVKJB51R2                NaN    2500      ONLY_DELIVERY
# 16118  4-CZNVVUUZJXDCR6                NaN    5000  DELIVERY_TAKEAWAY
# 16120  4-C2JWAKCFE7C2TJ                NaN    5000  DELIVERY_TAKEAWAY
# 16121  4-C2DKPANTSA51VE                NaN    5000  DELIVERY_TAKEAWAY
# 16122  4-C2NULJ6WCCCKLE                NaN    5000  DELIVERY_TAKEAWAY
# 16123  4-C2BVAKK1J7U3EX                NaN    5000      ONLY_DELIVERY
# 16124  4-C2MUAJN3UEWFJN                NaN   10000      ONLY_DELIVERY
# 16125  4-CYMUL4M3T2KGUE                NaN    5000  DELIVERY_TAKEAWAY
# 16126  4-CZEFR6AUNNXTLA                NaN    5000  DELIVERY_TAKEAWAY
# 16127  4-C2TVG3VEC752L2                NaN    5000  DELIVERY_TAKEAWAY
# 16129  4-CYVETVMAR7DVLX                NaN    5000  DELIVERY_TAKEAWAY
# 16130  4-C2MHKEVGRYXELT                NaN   10000      ONLY_DELIVERY
# 16131  4-CZNFTYKKVA3UN2                NaN    5000  DELIVERY_TAKEAWAY
# 16132         SGDD01192                NaN    3000  DELIVERY_TAKEAWAY
# 16134  4-C2AHJVATN7C2RE                NaN    5000  DELIVERY_TAKEAWAY
# 16135  4-C2DXFEK2R6KJTJ                NaN    5000  DELIVERY_TAKEAWAY
#
#                                                    promo
# 623                               No Promotion available
# 647    Enjoy 20% off min. spend $25 with promo code "...
# 893    Enjoy 20% off min. spend $25 with promo code "...
# 993                               No Promotion available
# 1009   Enjoy 20% off min. spend $25 with promo code "...
# 1039   Enjoy 20% off min. spend $25 with promo code "...
# 1043   50% off United Sports Double Shoot-Out Arcade ...
# 1146   Use "GRAB5313" to enjoy a $5 discount, min spe...
# 2165                              No Promotion available
# 2176                              No Promotion available
# 2232   S$10.00 off delivery fee with S$225.00 min. order
# 3831                              No Promotion available
# 4247                              No Promotion available
# 4284   Enjoy 20% off min. spend $25 with promo code "...
# 4374                              No Promotion available
# 4394                              No Promotion available
# 4412   Enjoy 20% off min. spend $25 with promo code "...
# 4453   Enjoy 20% off min. spend $25 with promo code "...
# 4515                              No Promotion available
# 4823                              No Promotion available
# 7814                              No Promotion available
# 8614   Enjoy 20% off min. spend $25 with promo code "...
# 9380     S$3.00 off delivery fee with S$30.00 min. order
# 9592                              No Promotion available
# 9597   Enjoy 20% off min. spend $25 with promo code "...
# 9645                              No Promotion available
# 9978   Enjoy 20% off min. spend $25 with promo code "...
# 10028  Enjoy 20% off min. spend $25 with promo code "...
# 10179                             No Promotion available
# 11273  Use 'TEATIME' for FREE delivery between 3PM to...
# 14076                             No Promotion available
# 15767                             No Promotion available
# 16112                             No Promotion available
# 16113                             No Promotion available
# 16114  Enjoy 20% off min. spend $25 with promo code "...
# 16116                             No Promotion available
# 16118                             No Promotion available
# 16120                             No Promotion available
# 16121  Use 'TEATIME' for FREE delivery between 3PM to...
# 16122                             No Promotion available
# 16123                             No Promotion available
# 16124  Enjoy 20% off min. spend $25 with promo code "...
# 16125                             No Promotion available
# 16126                             No Promotion available
# 16127                    20% off with S$30.00 min. order
# 16129                             No Promotion available
# 16130  Enjoy 20% off min. spend $25 with promo code "...
# 16131                             No Promotion available
# 16132                             No Promotion available
# 16134                             No Promotion available
# 16135  Use 'TEATIME' for FREE delivery between 3PM to...

# %%
#To check how many columns and rows the contain NaN value.51 columns have NaN values under delivery_cost_sds
rows_with_nan.shape
# Out:
# (51, 5)

# %%
delivery_df
# Out:
#               id_source  delivery_cost_sds  radius          delivery_options  \
# 0             SGDD01085                5.7    5000             ONLY_DELIVERY
# 1      4-CYTDLPUJEP53N6                5.7    3000             ONLY_DELIVERY
# 2             SGDD05605                5.6    5000         DELIVERY_TAKEAWAY
# 3             SGDD07548                5.6    5000             ONLY_DELIVERY
# 4      4-CY2ZLZLTT2EDJ2                5.7    5000         DELIVERY_TAKEAWAY
# ...                 ...                ...     ...                       ...
# 16131  4-CZNFTYKKVA3UN2                NaN    5000         DELIVERY_TAKEAWAY
# 16132         SGDD01192                NaN    3000         DELIVERY_TAKEAWAY
# 16133         SGDD00961                5.6    3000  DELIVERY_TAKEAWAY_DINEIN
# 16134  4-C2AHJVATN7C2RE                NaN    5000         DELIVERY_TAKEAWAY
# 16135  4-C2DXFEK2R6KJTJ                NaN    5000         DELIVERY_TAKEAWAY
#
#                                                    promo
# 0      Use 'TEATIME' for FREE delivery between 3PM to...
# 1      Use 'TEATIME' for FREE delivery between 3PM to...
# 2      Use 'TEATIME' for FREE delivery between 3PM to...
# 3      Use 'TEATIME' for FREE delivery between 3PM to...
# 4      Use 'TEATIME' for FREE delivery between 3PM to...
# ...                                                  ...
# 16131                             No Promotion available
# 16132                             No Promotion available
# 16133                             No Promotion available
# 16134                             No Promotion available
# 16135  Use 'TEATIME' for FREE delivery between 3PM to...
#
# [16136 rows x 5 columns]

# %%
grab_rest_name=grab_rest [['id_source','name']]
grab_rest_name
# Out:
#               id_source                         name
# 0             SGDD01085                Texas Chicken
# 1      4-CYTDLPUJEP53N6                       Subway
# 2             SGDD05605                     LiHO Tea
# 3             SGDD07548                     Wingstop
# 4      4-CY2ZLZLTT2EDJ2              Le Shrimp Ramen
# ...                 ...                          ...
# 16131  4-CZNFTYKKVA3UN2                 Minjiangkueh
# 16132         SGDD01192  The Modern Izakaya by Tatsu
# 16133         SGDD00961               Raj Restaurant
# 16134  4-C2AHJVATN7C2RE   Albismi Indian Muslim Food
# 16135  4-C2DXFEK2R6KJTJ  Zam Zam Indian Special Food
#
# [16136 rows x 2 columns]

# %%
# Using isna() method to create a boolean mask for NaN values
nan_mask_main = grab_rest_name.isna().any(axis=1)

# Filter the DataFrame to select rows with NaN values
names_with_nan = grab_rest_name[nan_mask_main]

# Display the rows with NaN values
print(names_with_nan)
# Out:
#              id_source name
# 628   4-CZDJJTWFC8BAAN  NaN
# 631   4-C2T2GYAJBEVFJN  NaN
# 688   4-CZLVCKMHNYTXNX  NaN
# 692   4-CZKKR7K2JJ22NT  NaN
# 702   4-CYNANF42AEVAVA  NaN
# 1031  4-CZEXEPEWN6KKEN  NaN

# %%
# List of values to delete
rows_to_delete = ['4-CZDJJTWFC8BAAN','4-C2T2GYAJBEVFJN','4-CZLVCKMHNYTXNX','4-CZKKR7K2JJ22NT', '4-CYNANF42AEVAVA','4-CZEXEPEWN6KKEN']  

# Filtering the DataFrame to exclude rows with specified values in the 'id_source' column
delivery_df = delivery_df[~delivery_df['id_source'].isin(rows_to_delete)]

# Alternatively, if you want to drop rows directly based on the specified values
# delivery_df = delivery_df.drop(delivery_df[delivery_df['id_source'].isin(values_to_delete)].index)

# Verify the DataFrame after deletion
delivery_df #now after 6 rows got deleted,now we have only 16130 rows and 5 columns
# Out:
#               id_source  delivery_cost_sds  radius          delivery_options  \
# 0             SGDD01085                5.7    5000             ONLY_DELIVERY
# 1      4-CYTDLPUJEP53N6                5.7    3000             ONLY_DELIVERY
# 2             SGDD05605                5.6    5000         DELIVERY_TAKEAWAY
# 3             SGDD07548                5.6    5000             ONLY_DELIVERY
# 4      4-CY2ZLZLTT2EDJ2                5.7    5000         DELIVERY_TAKEAWAY
# ...                 ...                ...     ...                       ...
# 16131  4-CZNFTYKKVA3UN2                NaN    5000         DELIVERY_TAKEAWAY
# 16132         SGDD01192                NaN    3000         DELIVERY_TAKEAWAY
# 16133         SGDD00961                5.6    3000  DELIVERY_TAKEAWAY_DINEIN
# 16134  4-C2AHJVATN7C2RE                NaN    5000         DELIVERY_TAKEAWAY
# 16135  4-C2DXFEK2R6KJTJ                NaN    5000         DELIVERY_TAKEAWAY
#
#                                                    promo
# 0      Use 'TEATIME' for FREE delivery between 3PM to...
# 1      Use 'TEATIME' for FREE delivery between 3PM to...
# 2      Use 'TEATIME' for FREE delivery between 3PM to...
# 3      Use 'TEATIME' for FREE delivery between 3PM to...
# 4      Use 'TEATIME' for FREE delivery between 3PM to...
# ...                                                  ...
# 16131                             No Promotion available
# 16132                             No Promotion available
# 16133                             No Promotion available
# 16134                             No Promotion available
# 16135  Use 'TEATIME' for FREE delivery between 3PM to...
#
# [16130 rows x 5 columns]

# %%
delivery_df.iloc[650:705] #just checking if the rows are deleted.
# Out:
#             id_source  delivery_cost_sds  radius   delivery_options  \
# 652  4-C2K3RYCDALCXVX               21.1   25000  DELIVERY_TAKEAWAY
# 653         SGDD10032               15.5   25000  DELIVERY_TAKEAWAY
# 654  4-CZCKL341LYMDBE               17.7   25000  DELIVERY_TAKEAWAY
# 655  4-C2BJMCKJSEETLA               23.0   25000  DELIVERY_TAKEAWAY
# 656  4-CYMFLRM3VNDGRN               20.2   25000  DELIVERY_TAKEAWAY
# 657  4-CY4XKE3TSCBFNT               22.1   25000      ONLY_DELIVERY
# 658         SGDD10157               17.3   25000  DELIVERY_TAKEAWAY
# 659  4-C2LFVVK1GCBCR6               24.6   25000  DELIVERY_TAKEAWAY
# 660         SGDD10141               23.0   25000  DELIVERY_TAKEAWAY
# 661  4-CZJET3DFPA2AFE               23.0   25000  DELIVERY_TAKEAWAY
# 662         SGDD10719               23.0   25000  DELIVERY_TAKEAWAY
# 663  4-CZEUT3UCT6XZV6               23.0   25000      ONLY_DELIVERY
# 664  4-CYLJWGMAVATCNN               18.1   25000  DELIVERY_TAKEAWAY
# 665         SGDD01793               23.0   25000  DELIVERY_TAKEAWAY
# 666         SGDD01561               21.2   25000  DELIVERY_TAKEAWAY
# 667         SGDD09806               23.0   25000  DELIVERY_TAKEAWAY
# 668  4-CZDTFE6GTY3AVJ               23.7   25000  DELIVERY_TAKEAWAY
# 669         SGDD05635               18.6   25000  DELIVERY_TAKEAWAY
# 670  4-C2DYCFVFL6XCFA               16.0   10000      ONLY_DELIVERY
# 671  4-CZKUPAXKRTX3JE                8.0   25000  DELIVERY_TAKEAWAY
# 672  4-C2LXJ8CFTJCAGJ               21.1   25000      ONLY_DELIVERY
# 673  4-CZEFT4NETY4GTE               23.0   25000  DELIVERY_TAKEAWAY
# 674  4-CYXJTB3DKEMJGN               17.8   25000  DELIVERY_TAKEAWAY
# 675  4-CZCTJXEWPBK1TA               17.7   25000      ONLY_DELIVERY
# 676  4-CY6XVVMCBA22VT               24.9   25000  DELIVERY_TAKEAWAY
# 677  4-CYMUL4NERZE2E6               24.9   25000  DELIVERY_TAKEAWAY
# 678         SGDD00905               24.9   25000  DELIVERY_TAKEAWAY
# 679         SGDD10292               17.0   10000      ONLY_DELIVERY
# 680  4-C2NYAYEGRGAWGE               24.2   25000  DELIVERY_TAKEAWAY
# 681         SGDD00721               23.4   25000  DELIVERY_TAKEAWAY
# 682  4-CZLBSFBYPGETTN               17.7   10000      ONLY_DELIVERY
# 683  4-C2AGVU2XJJN1VJ               17.9   10000      ONLY_DELIVERY
# 684         SGDD11783               24.9   25000  DELIVERY_TAKEAWAY
# 685         SGDD01452               23.0   25000  DELIVERY_TAKEAWAY
# 686         SGDD10358               23.0   25000  DELIVERY_TAKEAWAY
# 687  4-C2KFAE6UUE2TJJ               22.1   25000  DELIVERY_TAKEAWAY
# 689         SGDD09263               23.3   25000  DELIVERY_TAKEAWAY
# 690  4-CYWXBAUYRUBBUE               23.0   25000  DELIVERY_TAKEAWAY
# 691  4-CZLAVTKZWAJ2J2               23.0   25000      ONLY_DELIVERY
# 693  4-C2A2RJ31TYB2R6               16.1   10000      ONLY_DELIVERY
# 694  4-CYU2V2KKVKUDRT               23.0    2500  DELIVERY_TAKEAWAY
# 695  4-C2LCG3CHNRNHSE               17.7   10000      ONLY_DELIVERY
# 696  4-C2DJC6LBCNTZJE               19.0   10000      ONLY_DELIVERY
# 697         SGDD07606               24.9   25000  DELIVERY_TAKEAWAY
# 698         SGDD12123               21.2   25000  DELIVERY_TAKEAWAY
# 699  4-C2KKJ2LAN2L3GN                3.0   25000      ONLY_DELIVERY
# 700  4-C2NUJ4CFAJK2R2                5.0   25000      ONLY_DELIVERY
# 701         SGDD06876               22.9   25000  DELIVERY_TAKEAWAY
# 703         SGDD11819               24.9   25000  DELIVERY_TAKEAWAY
# 704         SGDD02908               24.9   25000  DELIVERY_TAKEAWAY
# 705         SGDD07978               23.0   25000  DELIVERY_TAKEAWAY
# 706         SGDD10543               24.5   25000  DELIVERY_TAKEAWAY
# 707         SGDD10509               18.8   25000  DELIVERY_TAKEAWAY
# 708  4-C2KCMA6VLB6WRN               15.0   25000      ONLY_DELIVERY
# 709         SGDD10401               24.9   25000  DELIVERY_TAKEAWAY
#
#                                                  promo
# 652  Use promo code "TRMFOOD5" at checkout to enjoy...
# 653                                    $3 OFF Del Fee!
# 654  Use 'TEATIME' for FREE delivery between 3PM to...
# 655                         Free Delivery  (June 2021)
# 656                             No Promotion available
# 657  Use 'TEATIME' for FREE delivery between 3PM to...
# 658                             No Promotion available
# 659  Use 'TEATIME' for FREE delivery between 3PM to...
# 660                             No Promotion available
# 661                             No Promotion available
# 662  Use 'TEATIME' for FREE delivery between 3PM to...
# 663                             No Promotion available
# 664                             No Promotion available
# 665                             No Promotion available
# 666  Use promo code "TRMFOOD5" at checkout to enjoy...
# 667                             No Promotion available
# 668  Use 'TEATIME' for FREE delivery between 3PM to...
# 669                              50% off Thai Iced Tea
# 670  Enjoy 20% off min. spend $25 with promo code "...
# 671                             No Promotion available
# 672  Enjoy 20% off min. spend $25 with promo code "...
# 673                             No Promotion available
# 674                             No Promotion available
# 675                             No Promotion available
# 676                             No Promotion available
# 677                             No Promotion available
# 678                             No Promotion available
# 679                             No Promotion available
# 680                             No Promotion available
# 681                             No Promotion available
# 682  Enjoy 20% off min. spend $25 with promo code "...
# 683                             No Promotion available
# 684                             No Promotion available
# 685                             No Promotion available
# 686                             No Promotion available
# 687                             No Promotion available
# 689                            20% off Grilled Fish 烤鱼
# 690                             No Promotion available
# 691     Free delivery, capped at $8 with Min spend $60
# 693  Enjoy 20% off min. spend $25 with promo code "...
# 694                $27 off Mix & Match Value Bundle 2B
# 695  Enjoy 20% off min. spend $25 with promo code "...
# 696  Enjoy 20% off min. spend $25 with promo code "...
# 697                  $0 Delivery Fee (min. $80 spend)!
# 698                             No Promotion available
# 699                             No Promotion available
# 700                             No Promotion available
# 701                             No Promotion available
# 703                             No Promotion available
# 704                             No Promotion available
# 705                             No Promotion available
# 706  Use 'TEATIME' for FREE delivery between 3PM to...
# 707                             No Promotion available
# 708                             No Promotion available
# 709    "WISMA5OFF", $5 discount with min spending $10!

# %%
#unique_identifiers
delivery_df ['delivery_options'].unique()
# Out:
# array(['ONLY_DELIVERY', 'DELIVERY_TAKEAWAY', 'DELIVERY_DINEIN',
#        'DELIVERY_TAKEAWAY_DINEIN'], dtype=object)

# %%
delivery_options_df =delivery_df[['delivery_options']]
delivery_options_df
# Out:
#                delivery_options
# 0                 ONLY_DELIVERY
# 1                 ONLY_DELIVERY
# 2             DELIVERY_TAKEAWAY
# 3                 ONLY_DELIVERY
# 4             DELIVERY_TAKEAWAY
# ...                         ...
# 16131         DELIVERY_TAKEAWAY
# 16132         DELIVERY_TAKEAWAY
# 16133  DELIVERY_TAKEAWAY_DINEIN
# 16134         DELIVERY_TAKEAWAY
# 16135         DELIVERY_TAKEAWAY
#
# [16130 rows x 1 columns]

# %%
# Create new columns with default False values
#delivery_options_df['delivery'] = False
#delivery_options_df['take_away'] = False
#delivery_options_df['dine_in'] = False

# Update values based on conditions
#delivery_options_df.loc[delivery_options_df['delivery_options'].str.contains('delivery', case=False), 'delivery'] = True
#delivery_options_df.loc[delivery_options_df['delivery_options'].str.contains('take', case=False), 'take_away'] = True
#delivery_options_df.loc[delivery_options_df['delivery_options'].str.contains('dine', case=False), 'dine_in'] = True

# Display the modified DataFrame
delivery_options_df
# Out:
#                delivery_options  delivery  take_away  dine_in
# 0                 ONLY_DELIVERY      True      False    False
# 1                 ONLY_DELIVERY      True      False    False
# 2             DELIVERY_TAKEAWAY      True       True    False
# 3                 ONLY_DELIVERY      True      False    False
# 4             DELIVERY_TAKEAWAY      True       True    False
# ...                         ...       ...        ...      ...
# 16131         DELIVERY_TAKEAWAY      True       True    False
# 16132         DELIVERY_TAKEAWAY      True       True    False
# 16133  DELIVERY_TAKEAWAY_DINEIN      True       True     True
# 16134         DELIVERY_TAKEAWAY      True       True    False
# 16135         DELIVERY_TAKEAWAY      True       True    False
#
# [16130 rows x 4 columns]
# C:\Users\Ros\AppData\Local\Temp\ipykernel_11256\3934425636.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   delivery_options_df['delivery'] = False
# C:\Users\Ros\AppData\Local\Temp\ipykernel_11256\3934425636.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   delivery_options_df['take_away'] = False
# C:\Users\Ros\AppData\Local\Temp\ipykernel_11256\3934425636.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   delivery_options_df['dine_in'] = False

# %%
# Create new columns with default False values
delivery_df['delivery'] = False
delivery_df['take_away'] = False
delivery_df['dine_in'] = False

# Update values based on conditions
delivery_df.loc[delivery_df['delivery_options'].str.contains('delivery', case=False), 'delivery'] = True
#For the 'delivery' column, it checks if the 'delivery_options' column contains the word 'delivery' (case insensitive), and if so, sets the corresponding value in the 'delivery' column to True.
delivery_df.loc[delivery_df['delivery_options'].str.contains('take', case=False), 'take_away'] = True
# For the 'take_away' column, it checks if the 'delivery_options' column contains the word 'take' (case insensitive), and if so, sets the corresponding value in the 'take_away' column to True.
delivery_df.loc[delivery_df['delivery_options'].str.contains('dine', case=False), 'dine_in'] = True

# Display the modified DataFrame
delivery_df
# Out:
# C:\Users\Ros\AppData\Local\Temp\ipykernel_11256\1643916875.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   delivery_df['delivery'] = False
# C:\Users\Ros\AppData\Local\Temp\ipykernel_11256\1643916875.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   delivery_df['take_away'] = False
# C:\Users\Ros\AppData\Local\Temp\ipykernel_11256\1643916875.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   delivery_df['dine_in'] = False
#               id_source  delivery_cost_sds  radius          delivery_options  \
# 0             SGDD01085                5.7    5000             ONLY_DELIVERY
# 1      4-CYTDLPUJEP53N6                5.7    3000             ONLY_DELIVERY
# 2             SGDD05605                5.6    5000         DELIVERY_TAKEAWAY
# 3             SGDD07548                5.6    5000             ONLY_DELIVERY
# 4      4-CY2ZLZLTT2EDJ2                5.7    5000         DELIVERY_TAKEAWAY
# ...                 ...                ...     ...                       ...
# 16131  4-CZNFTYKKVA3UN2                NaN    5000         DELIVERY_TAKEAWAY
# 16132         SGDD01192                NaN    3000         DELIVERY_TAKEAWAY
# 16133         SGDD00961                5.6    3000  DELIVERY_TAKEAWAY_DINEIN
# 16134  4-C2AHJVATN7C2RE                NaN    5000         DELIVERY_TAKEAWAY
# 16135  4-C2DXFEK2R6KJTJ                NaN    5000         DELIVERY_TAKEAWAY
#
#                                                    promo  delivery  take_away  \
# 0      Use 'TEATIME' for FREE delivery between 3PM to...      True      False
# 1      Use 'TEATIME' for FREE delivery between 3PM to...      True      False
# 2      Use 'TEATIME' for FREE delivery between 3PM to...      True       True
# 3      Use 'TEATIME' for FREE delivery between 3PM to...      True      False
# 4      Use 'TEATIME' for FREE delivery between 3PM to...      True       True
# ...                                                  ...       ...        ...
# 16131                             No Promotion available      True       True
# 16132                             No Promotion available      True       True
# 16133                             No Promotion available      True       True
# 16134                             No Promotion available      True       True
# 16135  Use 'TEATIME' for FREE delivery between 3PM to...      True       True
#
#        dine_in
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
# ...        ...
# 16131    False
# 16132    False
# 16133     True
# 16134    False
# 16135    False
#
# [16130 rows x 8 columns]

# %%
delivery_df
# Out:
#               id_source  delivery_cost_sds  radius          delivery_options  \
# 0             SGDD01085                5.7    5000             ONLY_DELIVERY
# 1      4-CYTDLPUJEP53N6                5.7    3000             ONLY_DELIVERY
# 2             SGDD05605                5.6    5000         DELIVERY_TAKEAWAY
# 3             SGDD07548                5.6    5000             ONLY_DELIVERY
# 4      4-CY2ZLZLTT2EDJ2                5.7    5000         DELIVERY_TAKEAWAY
# ...                 ...                ...     ...                       ...
# 16131  4-CZNFTYKKVA3UN2                NaN    5000         DELIVERY_TAKEAWAY
# 16132         SGDD01192                NaN    3000         DELIVERY_TAKEAWAY
# 16133         SGDD00961                5.6    3000  DELIVERY_TAKEAWAY_DINEIN
# 16134  4-C2AHJVATN7C2RE                NaN    5000         DELIVERY_TAKEAWAY
# 16135  4-C2DXFEK2R6KJTJ                NaN    5000         DELIVERY_TAKEAWAY
#
#                                                    promo  delivery  take_away  \
# 0      Use 'TEATIME' for FREE delivery between 3PM to...      True      False
# 1      Use 'TEATIME' for FREE delivery between 3PM to...      True      False
# 2      Use 'TEATIME' for FREE delivery between 3PM to...      True       True
# 3      Use 'TEATIME' for FREE delivery between 3PM to...      True      False
# 4      Use 'TEATIME' for FREE delivery between 3PM to...      True       True
# ...                                                  ...       ...        ...
# 16131                             No Promotion available      True       True
# 16132                             No Promotion available      True       True
# 16133                             No Promotion available      True       True
# 16134                             No Promotion available      True       True
# 16135  Use 'TEATIME' for FREE delivery between 3PM to...      True       True
#
#        dine_in
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
# ...        ...
# 16131    False
# 16132    False
# 16133     True
# 16134    False
# 16135    False
#
# [16130 rows x 8 columns]
